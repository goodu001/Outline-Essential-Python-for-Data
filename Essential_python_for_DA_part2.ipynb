# %% [markdown]
# <a href="https://colab.research.google.com/github/goodu001/Outline-Essential-Python-for-Data/blob/main/Essential_python_for_DA_part2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
## numpy
import numpy as np
import pandas as pd

# %%
# numpy : numerical python
friends = ["DumP", "John", "Jane"]

# %%
type(friends)
# Out:
# list

# %%
arr_friends = np.array(friends) # vector in R

# %%
# examscores
scores = [90, 80, 95, 100, 120, 500]
arr_scores = np.array(scores)

# %%
np.mean(arr_scores)
# Out:
# 164.16666666666666

# %%
np.median(arr_scores)
# Out:
# 97.5

# %%
np.std(arr_scores)
# Out:
# 150.6767142667447

# %%
## array 2d
twod_list = [[1,2,3], [4,5,6], [7,8,9]]
arr_2d = np.array(twod_list)

# %%
twod_list[1][2]
# Out:
# 6

# %%
arr_2d[0][0]
# Out:
# 1

# %%
# martrix multiplication (dot)

mat1 = np.array([[1,2], [3,4]])
mat2 = np.array([[5,6], [7,8]])

# %%
mat1.dot(mat2)
# Out:
# array([[19, 22],
#        [43, 50]])

# %%
np.dot(mat1, mat2)
# Out:
# array([[19, 22],
#        [43, 50]])

# %%
# prompt: create a student dataframe with 5 column 10 rows using pandas

import pandas as pd
import numpy as np

# Create a sample student DataFrame
num_rows = 10
student_data = {
    'StudentID': np.arange(1, num_rows + 1),
    'Name': ['Student' + str(i) for i in range(1, num_rows + 1)],
    'Age': np.random.randint(18, 22, size=num_rows),
    'Grade': np.random.randint(80, 100, size=num_rows),
    'Major': ['Math', 'CS', 'Physics', 'Biology', 'Chemistry', 'Engineering', 'Economics', 'History', 'English', 'Psychology'][:num_rows]
}

df_students = pd.DataFrame(student_data)
df_students
# Out:
#    StudentID       Name  Age  Grade        Major
# 0          1   Student1   19     81         Math
# 1          2   Student2   21     87           CS
# 2          3   Student3   18     96      Physics
# 3          4   Student4   18     80      Biology
# 4          5   Student5   21     85    Chemistry
# 5          6   Student6   19     97  Engineering
# 6          7   Student7   18     95    Economics
# 7          8   Student8   18     94      History
# 8          9   Student9   18     91      English
# 9         10  Student10   18     99   Psychology

# %%
df_students["Age"].mean()
# Out:
# 18.8

# %%
np.mean(df_students["Age"])
# Out:
# 18.8

# %%
df_students.columns
# Out:
# Index(['StudentID', 'Name', 'Age', 'Grade', 'Major'], dtype='object')

# %%
df_students[["StudentID","Name"]].head()
# Out:
#    StudentID      Name
# 0          1  Student1
# 1          2  Student2
# 2          3  Student3
# 3          4  Student4
# 4          5  Student5

# %%
df_students.query("Age > 20") ## where clause
# Out:
#    StudentID      Name  Age  Grade      Major
# 1          2  Student2   21     87         CS
# 4          5  Student5   21     85  Chemistry

# %%
df_students.query("Major == 'Math' and Grade > 80")[["Name", "Grade", "Major"]]
# Out:
#        Name  Grade Major
# 0  Student1     81  Math

# %%
# sklearn = machine learning model
# Python ML AI > R

from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeRegressor
from sklearn.neighbors import KNeighborsRegressor
from sklearn.ensemble import RandomForestRegressor

# %%
mtcars = pd.read_excel('mtcars.xlsx')
mtcars.head()
# Out:
#     hp   mpg  cyl   disp  drat     wt   qsec  vs  am  gear  ...  Unnamed: 14  \
# 0  110  21.0    6  160.0  3.90  2.620  16.46   0   1     4  ...          NaN
# 1  110  21.0    6  160.0  3.90  2.875  17.02   0   1     4  ...          NaN
# 2   93  22.8    4  108.0  3.85  2.320  18.61   1   1     4  ...          mpg
# 3  110  21.4    6  258.0  3.08  3.215  19.44   1   0     3  ...          NaN
# 4  175  18.7    8  360.0  3.15  3.440  17.02   0   0     3  ...            1
#
#    Unnamed: 15 Unnamed: 16 Unnamed: 17 Unnamed: 18 Unnamed: 19 Unnamed: 20  \
# 0          NaN         NaN         NaN         NaN         NaN         NaN
# 1          NaN         NaN         NaN         NaN         NaN         NaN
# 2          NaN         NaN         NaN         NaN         NaN         NaN
# 3          NaN         NaN         NaN         NaN         NaN         NaN
# 4          NaN         NaN         NaN         NaN         NaN         NaN
#
#   Unnamed: 21 Unnamed: 22 Unnamed: 23
# ...

# %%
# prepare data
x = mtcars.drop("mpg", axis=1)
y = mtcars["mpg"]

# %%
x
# Out:
#      hp  cyl   disp  drat     wt   qsec  vs  am  gear  carb  ...  Unnamed: 14  \
# 0   110    6  160.0  3.90  2.620  16.46   0   1     4     4  ...          NaN
# 1   110    6  160.0  3.90  2.875  17.02   0   1     4     4  ...          NaN
# 2    93    4  108.0  3.85  2.320  18.61   1   1     4     1  ...          mpg
# 3   110    6  258.0  3.08  3.215  19.44   1   0     3     1  ...          NaN
# 4   175    8  360.0  3.15  3.440  17.02   0   0     3     2  ...            1
# 5   105    6  225.0  2.76  3.460  20.22   1   0     3     1  ...          NaN
# 6   245    8  360.0  3.21  3.570  15.84   0   0     3     4  ...          mpg
# 7    62    4  146.7  3.69  3.190  20.00   1   0     4     2  ...          NaN
# 8    95    4  140.8  3.92  3.150  22.90   1   0     4     2  ...          NaN
# 9   123    6  167.6  3.92  3.440  18.30   1   0     4     4  ...    -0.852162
# 10  123    6  167.6  3.92  3.440  18.90   1   0     4     4  ...    -0.847551
# ...

# %%
# ml workflow
# 1. split data
# 2. train
# 3. score
# 4. evaluate

# %%
# split data
# set.seed(42)
x_train, x_test, y_train, y_test = train_test_split(
    x, y, test_size=0.25, random_state=42
)

# %%
# train model
# no free lunch -> experiment
# automl
model = KNeighborsRegressor()
model.fit(x_train, y_train)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-58-be5829abbba2> in <cell line: 3>()
#       1 # train model
#       2 model = KNeighborsRegressor()
# ----> 3 model.fit(x_train, y_train)
#
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py in wrapper(estimator, *args, **kwargs)
#    1471                 )
#    1472             ):
# -> 1473                 return fit_method(estimator, *args, **kwargs)
#    1474
#    1475         return wrapper
#
# /usr/local/lib/python3.10/dist-packages/sklearn/neighbors/_regression.py in fit(self, X, y)
#     225             The fitted k-nearest neighbors regressor.
#     226         """
# --> 227         return self._fit(X, y)
#     228
#     229     def predict(self, X):
#
# /usr/local/lib/python3.10/dist-packages/sklearn/neighbors/_base.py in _fit(self, X, y)
#     473         if self._get_tags()["requires_y"]:
# ...

# %%
# prediction
p = model.predict(x_test)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-52-25288d7e9c8b> in <cell line: 2>()
#       1 # prediction
# ----> 2 p = model.predict(x_test)
#
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_base.py in predict(self, X)
#     304             Returns predicted values.
#     305         """
# --> 306         return self._decision_function(X)
#     307
#     308     def _set_intercept(self, X_offset, y_offset, X_scale):
#
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_base.py in _decision_function(self, X)
#     283         check_is_fitted(self)
#     284
# --> 285         X = self._validate_data(X, accept_sparse=["csr", "csc", "coo"], reset=False)
#     286         coef_ = self.coef_
#     287         if coef_.ndim == 1:
#
# ...

# %%
# evaluate R-squared
model.score(x_test, y_test)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-53-a073824583a9> in <cell line: 2>()
#       1 # evaluate R-squared
# ----> 2 model.score(x_test, y_test)
#
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py in score(self, X, y, sample_weight)
#     846         from .metrics import r2_score
#     847
# --> 848         y_pred = self.predict(X)
#     849         return r2_score(y, y_pred, sample_weight=sample_weight)
#     850
#
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_base.py in predict(self, X)
#     304             Returns predicted values.
#     305         """
# --> 306         return self._decision_function(X)
#     307
#     308     def _set_intercept(self, X_offset, y_offset, X_scale):
#
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_base.py in _decision_function(self, X)
#     283         check_is_fitted(self)
# ...
